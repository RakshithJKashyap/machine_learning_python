# %%
import pandas as pd

# %%
df = pd.read_excel('seminar_topic_allotment.xlsx',nrows= 90,header = 3)
df
# Out:
#     Sr No      USN       Name  \
# 0       1  PUCS001    ABIGAIL
# 1       2  PUCS002  ALEXANDRA
# 2       3  PUCS003     ALISON
# 3       4  PUCS004     AMANDA
# 4       5  PUCS006     AMELIA
# ..    ...      ...        ...
# 81     82  PUCS085   VIRGINIA
# 82     83  PUCS086      WANDA
# 83     84  PUCS087      WENDY
# 84     85  PUCS088     YVONNE
# 85     86  PUCS089        ZOE
#
#                                                 Topic  NOTES
# 0                              LOCATION BASED SERVICE    NaN
# 1                           COMPUTATIONAL PHOTOGRAPHY    NaN
# 2                      BLUETOOTH BASED SENSOR NETWORK    NaN
# 3                                    ROVER TECHNOLOGY    NaN
# 4                                    HUMAN ID IMPLANT    NaN
# ..                                                ...    ...
# 81  EPICS - ELECTROMECHANICAL HUMAN MACHINE INTERA...    NaN
# 82   HEART FAILURE ALERT SYSTEM USING RFID TECHNOLOGY    NaN
# ...

# %%
df = df.set_index('Sr No')
df.head()
# Out:
#            USN       Name                           Topic  NOTES
# Sr No
# 1      PUCS001    ABIGAIL          LOCATION BASED SERVICE    NaN
# 2      PUCS002  ALEXANDRA       COMPUTATIONAL PHOTOGRAPHY    NaN
# 3      PUCS003     ALISON  BLUETOOTH BASED SENSOR NETWORK    NaN
# 4      PUCS004     AMANDA                ROVER TECHNOLOGY    NaN
# 5      PUCS006     AMELIA                HUMAN ID IMPLANT    NaN
